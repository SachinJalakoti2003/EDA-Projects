# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# # Data Cleaning

# %%
df['Production (Tons)']=df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\3662165837.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production (Tons)']=df["Production (Tons)"].str.replace(".","")
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\3662165837.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\3662165837.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df["Acreage (Hectare)"].isna().sum()
# Out:
# 1

# %%
df[df["Acreage (Hectare)"].isna()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df=df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.drop(["index","Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df["Production (Tons)"]=df["Production (Tons)"].astype(float)
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].astype(float)
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].astype(float)
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                        object
# Continent                      object
# Production (Tons)             float64
# Production per Person (Kg)    float64
# Acreage (Hectare)             float64
# Yield (Kg / Hectare)          float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                       102
# Continent                       6
# Production (Tons)             102
# Production per Person (Kg)    101
# Acreage (Hectare)             101
# Yield (Kg / Hectare)          102
# dtype: int64

# %%
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production (Tons)"])

plt.subplot(2,2,2)
sns.distplot(df["Production per Person (Kg)"])


plt.subplot(2,2,3)
sns.distplot(df["Acreage (Hectare)"])

plt.subplot(2,2,4)
sns.distplot(df["Yield (Kg / Hectare)"])
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\2664982285.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production (Tons)"])
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\2664982285.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production (Tons)"])

plt.subplot(2,2,2)
sns.boxplot(df["Production per Person (Kg)"])


plt.subplot(2,2,3)
sns.boxplot(df["Acreage (Hectare)"])

plt.subplot(2,2,4)
sns.boxplot(df["Yield (Kg / Hectare)"])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Production (Tons)  Production per Person (Kg)  Acreage (Hectare)  \
# count       1.020000e+02                  102.000000       1.020000e+02
# mean        1.850372e+07               112952.435755       2.498981e+05
# std         8.419149e+07               176651.341929       1.137003e+06
# min         1.000000e+00                    0.000000       0.000000e+00
# 25%         6.251875e+04                 3671.910000       1.104000e+03
# 50%         1.440044e+06                25572.500000       1.655800e+04
# 75%         6.426824e+06               146384.750000       8.047400e+04
# max         7.686784e+08               951087.000000       1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %%
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Spain                  394.0
# Lebanon                 97.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production (Tons)_Percentage"]=df_new["Production (Tons)"]*100/df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  Production (Tons)_Percentage
# Country
# Brazil           768678382.0                  4.072729e+01
# India            348448000.0                  1.846200e+01
# China            123059739.0                  6.520138e+00
# Thailand          87468496.0                  4.634389e+00
# Pakistan          65450704.0                  3.467809e+00
# ...                      ...                           ...
# Spain                  394.0                  2.087551e-05
# Lebanon                 97.0                  5.139401e-06
# Singapore               50.0                  2.649176e-06
# Samoa                   12.0                  6.358022e-07
# Syria                    1.0                  5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production (Tons)_Percentage"].plot(kind="pie",autopct="%2f")
# Out:
# <Axes: ylabel='Production (Tons)_Percentage'>

# %%
df_new["Production (Tons)"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax=sns.barplot(data=df.head(),x="Country",y="Production (Tons)")

# %%
ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
ax.xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
# ----> 2 ax.xticklabels(ax.get_xticklabels(),rotation=90)
#       3 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'xticklabels'

# %%
df_acr=df.sort_values("Acreage (Hectare)",ascending=False).head()
ax=sns.barplot(data=df_acr,x="Country",y="Production (Tons)")
ax.xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 3
#       1 df_acr=df.sort_values("Acreage (Hectare)",ascending=False).head()
#       2 ax=sns.barplot(data=df_acr,x="Country",y="Production (Tons)")
# ----> 3 ax.xticklabels(ax.get_xticklabels(),rotation=90)
#       4 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'xticklabels'

# %%
df_yeild=df.sort_values("Yield (Kg / Hectare)",ascending=False)
ax=sns.barplot(data=df_yeild.head(10),x="Country",y="Yield (Kg / Hectare)")
ax.xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 3
#       1 df_yeild=df.sort_values("Yield (Kg / Hectare)",ascending=False)
#       2 ax=sns.barplot(data=df_yeild.head(10),x="Country",y="Yield (Kg / Hectare)")
# ----> 3 ax.xticklabels(ax.get_xticklabels(),rotation=90)
#       4 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'xticklabels'

# %%
df.corr()
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.015000
# Production per Person (Kg)           0.015000                    1.000000
# Acreage (Hectare)                    0.997550                    0.012557
# Yield (Kg / Hectare)                 0.132812                    0.017999
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)
# Production (Tons)                    0.997550              0.132812
# Production per Person (Kg)           0.012557              0.017999
# Acreage (Hectare)                    1.000000              0.113433
# ...

# %%
sns.heatmap(df.corr(),annot=True,cmap="tab20c")
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\2700469079.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="tab20c")
# <Axes: >

# %%
sns.scatterplot(data=df,x="Acreage (Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %%
sns.scatterplot(data=df,x="Yield (Kg / Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production (Tons)'>

# %%
df_continent=df.groupby("Continent").sum()
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_11204\1663322524.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_continent=df.groupby("Continent").sum()

# %%
df_continent
# Out:
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                 2332636.293
# Asia                 721930425.0                 1857769.303
# Europe                    5823.0                     536.000
# North America        173995947.0                 3796081.508
# Oceania               36177574.0                   28593.605
# South America        865588126.0                 3505531.738
#
#                Acreage (Hectare)  Yield (Kg / Hectare)
# Continent
# Africa                 1439089.0             2142107.5
# Asia                  10608319.0             1171871.4
# Europe                      71.0              131870.9
# North America          1581983.0             1082602.4
# Oceania                 490909.0              162419.1
# South America         11369236.0              677192.7

# %%
df_continent["Production (Tons)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64
